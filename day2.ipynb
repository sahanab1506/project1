# %% [markdown]
# <a href="https://colab.research.google.com/github/sahanab1506/project1/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num = int(input("Enter number:"))
  print(num)

except:
  print("Invalid input")
# Out:
# Enter number:67
# 67
