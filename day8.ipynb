# %% [markdown]
# <a href="https://colab.research.google.com/github/sahanab1506/project1/blob/main/day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    "region":["north","south","west",],
    "product":["laptop","mobile","tab"],
    "sales":[25000,15000,76000]
    }
df=pd.DataFrame(data)
print(df)
# Out:
#   region product  sales
# 0  north  laptop  25000
# 1  south  mobile  15000
# 2   west     tab  76000
