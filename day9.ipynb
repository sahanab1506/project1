# %% [markdown]
# <a href="https://colab.research.google.com/github/sahanab1506/project1/blob/main/day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
marks=[45,34,87,95,78,43,65,18,91,38,50,85]
plt.hist(marks)
plt.title("student marks distribution")
plt.xlabel("marks")
plt.ylabel("number of students")
plt.show()
