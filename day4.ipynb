# %% [markdown]
# <a href="https://colab.research.google.com/github/sahanab1506/project1/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
marks=np.array([90,87,67,57,85])
print(marks[3])
# Out:
# 57

# %%
marks=np.array([90,76,89,63,78])
print(marks[1:2])
# Out:
# [76]

# %%
scores=[89,74,65,24,11]
total=sum(scores)
average = total/len(scores)
highest = max(scores)
lowest = min(scores)

print("students scores:",scores)
print("total marks:",total)
print("average marks:",average)
print("highest marks:",highest)
print("lowest marks:",lowest)
# Out:
# students scores: [89, 74, 65, 24, 11]
# total marks: 263
# average marks: 52.6
# highest marks: 89
# lowest marks: 11
