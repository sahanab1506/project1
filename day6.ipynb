# %% [markdown]
# <a href="https://colab.research.google.com/github/sahanab1506/project1/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
uploaded=files.upload()
df=pd.read_csv("customers-100.csv")
print(df.tail(3))
# Out:
#      <input type="file" id="files-1130e54e-e86b-44f9-9022-4dce405404c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1130e54e-e86b-44f9-9022-4dce405404c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = {
'Name':['john','mari','selvi','vino'],
'Sales':[1000,None,2000,None]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Sales
# 0   john  1000.0
# 1   mari     NaN
# 2  selvi  2000.0
# 3   vino     NaN

# %%
print(df.isnull())
# Out:
#     Name  Sales
# 0  False  False
# 1  False   True
# 2  False  False
# 3  False   True

# %%
clean_df=df.dropna()
print(clean_df)
# Out:
#     Name   Sales
# 0   john  1000.0
# 2  selvi  2000.0

# %%
df.fillna(0,inplace=True)
print(df)
# Out:
#     Name   Sales
# 0   john  1000.0
# 1   mari     0.0
# 2  selvi  2000.0
# 3   vino     0.0
