# %% [markdown]
# <a href="https://colab.research.google.com/github/sahanab1506/project1/blob/main/day1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mark1=int(input("Enter M1:"))
Mark2=int(input("Enter M2:"))
Mark3=int(input("Enter M3:"))

total = Mark1 + Mark2 + Mark3
Average=total/3

print("total:",total)
print("Average:",Average)

if Average >= 90:
    print("Grade: A")
elif Average >= 50:
    print("Grade: B")
else:
    print("Grade: C")
# Out:
# Enter M1:56
# Enter M2:90
# Enter M3:79
# total: 225
# Average: 75.0
# Grade: B
